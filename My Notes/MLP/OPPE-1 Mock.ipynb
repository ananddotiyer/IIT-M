# %% [markdown]
# Preamble: Download breast cancer dataset from sklearn
# and answer the following questions:

# %%
from sklearn.datasets import load_breast_cancer

# %%
data = load_breast_cancer(as_frame=True)

# %%
data.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename', 'data_module'])

# %%
data.frame.shape
# Out:
# (569, 31)

# %%
data.target.unique()
# Out:
# array([0, 1])

# %%
data.frame[data.target== 0]
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 563        20.92         25.09          143.00     1347.0          0.10990
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
#
# ...

# %%
data.data.info() # no non-numeric features
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 30 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   mean radius              569 non-null    float64
#  1   mean texture             569 non-null    float64
#  2   mean perimeter           569 non-null    float64
#  3   mean area                569 non-null    float64
#  4   mean smoothness          569 non-null    float64
#  5   mean compactness         569 non-null    float64
#  6   mean concavity           569 non-null    float64
#  7   mean concave points      569 non-null    float64
#  8   mean symmetry            569 non-null    float64
#  9   mean fractal dimension   569 non-null    float64
#  10  radius error             569 non-null    float64
#  11  texture error            569 non-null    float64
#  12  perimeter error          569 non-null    float64
# ...

# %%
data = data.data

# %%
data
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %%
data[['mean perimeter', 'mean radius']].corr()
# Out:
#                 mean perimeter  mean radius
# mean perimeter        1.000000     0.997855
# mean radius           0.997855     1.000000

# %%
import numpy as np

X = [[7, 16, 31], [np.nan, np.nan, 66], [12, 5, np.nan],[98, np.nan, 92]]

# %%
from sklearn.impute import SimpleImputer
si = SimpleImputer(strategy='mean')
si.fit_transform(X)
# Out:
# array([[ 7. , 16. , 31. ],
#        [39. , 10.5, 66. ],
#        [12. ,  5. , 63. ],
#        [98. , 10.5, 92. ]])

# %%
X =  [[1, 1], [2, 3],[10,100]]

# %%
from sklearn.preprocessing import FunctionTransformer
ft = FunctionTransformer(np.log10)
ft.fit_transform(X)
# Out:
# array([[0.        , 0.        ],
#        [0.30103   , 0.47712125],
#        [1.        , 2.        ]])

# %%
import pandas as pd
data = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data', header=None, names=['sepal length', 'sepal width', 'petal length', 'petal width','label'])
data
# Out:
#      sepal length  sepal width  petal length  petal width           label
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
from sklearn.preprocessing import PolynomialFeatures

poly = PolynomialFeatures(degree=2)
poly.fit_transform(data.iloc[: ,:-1]).shape
# Out:
# (150, 15)

# %%
from sklearn.datasets import fetch_california_housing
X, y = fetch_california_housing(return_X_y=True)

# %%
y
# Out:
# array([4.526, 3.585, 3.521, ..., 0.923, 0.847, 0.894])

# %%
X = X[:1000, :]
y = y[:1000]

# %%
from sklearn.feature_selection import SelectPercentile, mutual_info_regression

sp = SelectPercentile(mutual_info_regression, percentile=10)
(sp.fit_transform(X, y)).shape
# Out:
# (1000, 1)

# %%
from sklearn.datasets import fetch_california_housing
X, y = fetch_california_housing(return_X_y=True)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# %%
X_train.shape
# Out:
# (16512, 8)

# %%
from sklearn.dummy import DummyRegressor
dummy = DummyRegressor(strategy='mean')
dummy.fit(X_train, y_train)
# Out:
# DummyRegressor()

# %%
r2_score(y_test, dummy.predict(X_test))
# Out:
# -0.0393444964686247

# %%
from sklearn.linear_model import SGDRegressor
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error

pipe = Pipeline([('scaler', MinMaxScaler()), ('sgd', SGDRegressor())])
pipe.fit(X_train, y_train)
mean_absolute_error(y_train, pipe.predict(X_train))
# Out:
# 0.5766039586403665

# %%
mean_absolute_error(y_test, pipe.predict(X_test))
# Out:
# 0.5596747596757825

# %%
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
cross_val_score(lr, X, y, cv=5)
# Out:
# array([0.54866323, 0.46820691, 0.55078434, 0.53698703, 0.66051406])

# %%
from sklearn.datasets import load_diabetes
X, y = load_diabetes(as_frame=True, return_X_y=True)
X.shape
# Out:
# (442, 10)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=10)

# %%
X_train.columns
# Out:
# Index(['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6'], dtype='object')

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression


pipe = Pipeline([('scaler', StandardScaler()), ('lr', LinearRegression())])
pipe.fit(X_train, y_train)
pipe.score(X_test, y_test)
# Out:
# 0.5341962544929234

# %%
X_train
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 252  0.005383 -0.044642  0.059541 -0.056166  0.024574  0.052861 -0.043401
# 416 -0.027310 -0.044642  0.080019  0.098763 -0.002945  0.018101 -0.017629
# 418  0.009016 -0.044642 -0.024529 -0.026328  0.098876  0.094196  0.070730
# 163  0.016281  0.050680  0.072474  0.076958 -0.008449  0.005575 -0.006584
# 253  0.081666 -0.044642  0.033673  0.008101  0.052093  0.056619 -0.017629
# ..        ...       ...       ...       ...       ...       ...       ...
# 369 -0.009147 -0.044642  0.037984 -0.040099 -0.024960 -0.003819 -0.043401
# 320 -0.023677 -0.044642  0.030440 -0.005671  0.082364  0.092004 -0.017629
# 15  -0.052738  0.050680 -0.018062  0.080401  0.089244  0.107662 -0.039719
# 125 -0.005515  0.050680 -0.008362 -0.002228 -0.033216 -0.063630 -0.036038
# 265 -0.034575  0.050680 -0.025607 -0.017147  0.001183 -0.002880  0.008142
#
#            s4        s5        s6
# 252  0.050914 -0.004220 -0.030072
# ...

# %%
pipe[-1].coef_
# Out:
# array([ -0.18524015, -10.74395358,  23.97068421,  15.44649018,
#        -33.63629412,  19.07747445,   3.87751116,  10.51831194,
#         34.15440847,   1.91362494])

# %%
from sklearn.linear_model import RidgeCV
alphalist = np.logspace(-4, 0, num=20)
rcv = RidgeCV(cv=5, alphas=alphalist, scoring='neg_mean_absolute_error')
rcv.fit(X_train, y_train)
rcv.best_score_
# Out:
# -45.14288569176621

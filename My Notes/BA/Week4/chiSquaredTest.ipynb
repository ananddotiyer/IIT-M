# %% [markdown]
# **Import packages**

# %%
import numpy as np
import pandas as pd
from scipy import stats

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-cb1d5fb9-dce8-4396-a423-99d55077e469" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cb1d5fb9-dce8-4396-a423-99d55077e469">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving chiSquare.csv to chiSquare (1).csv

# %%
import io
df2 = pd.read_csv(io.BytesIO(uploaded['chiSquare.csv']))

# %%
df2.head()
# Out:
#       City Brand
# 0   Mumbai     A
# 1  Chennai     C
# 2   Mumbai     A
# 3   Mumbai     C
# 4  Chennai     C

# %%
contingTab = pd.crosstab(df2.City, df2.Brand, margins=True)

# %%
contingTab
# Out:
# Brand      A    B    C  All
# City
# Chennai  165   47  191  403
# Mumbai   279   73  225  577
# All      444  120  416  980

# %% [markdown]
# **Calculate the expected frequency**

# %%
contingTab['A']
# Out:
# City
# Chennai    165
# Mumbai     279
# All        444
# Name: A, dtype: int64

# %%
contingTab['A']['Chennai']
# Out:
# 165

# %%
contingTab['All']['All']
# Out:
# 980

# %%
contingTab.transpose()
# Out:
# City   Chennai  Mumbai  All
# Brand
# A          165     279  444
# B           47      73  120
# C          191     225  416
# All        403     577  980

# %%
cities = list(df2['City'].unique())
brands = list(df2['Brand'].unique())

exp1 = {}

for i in cities:
  exp2 = {}
  for j in brands:
    exp2[j] = contingTab.transpose()[i]['All'] * contingTab[j]['All'] / (contingTab['All']['All'])

  exp1[i] = exp2

# %%
403*444/980
# Out:
# 182.58367346938775

# %%
exp1
# Out:
# {'Chennai': {'A': 182.58367346938775,
#   'B': 49.3469387755102,
#   'C': 171.06938775510204},
#  'Mumbai': {'A': 261.41632653061225,
#   'B': 70.65306122448979,
#   'C': 244.93061224489796}}

# %% [markdown]
# **Chi square calculation**

# %%
chiSquareCal = 0
for i in cities:
  for j in brands:
    val = (contingTab.transpose()[i][j] - exp1[i][j])**2/exp1[i][j]
    chiSquareCal = chiSquareCal + val

# %%
chiSquareCal
# Out:
# 7.009543616823935

# %% [markdown]
# **Degrees of freedom**

# %%
dof = (len(cities)-1) * (len(brands)-1)

# %%
dof
# Out:
# 2

# %%
stats.chi2.ppf(1-0.05, df=dof)
# Out:
# 5.991464547107979

# %% [markdown]
# **Shortcut to the chi-squared test**

# %%
contab = np.array([contingTab.transpose()['Chennai'][0:3].values,
                  contingTab.transpose()['Mumbai'][0:3].values])
stats.chi2_contingency(contab)
# Out:
# (7.009543616823934,
#  0.03005363054744611,
#  2,
#  array([[182.58367347,  49.34693878, 171.06938776],
#         [261.41632653,  70.65306122, 244.93061224]]))

# %%
1 - stats.chi2.cdf(chiSquareCal, dof)
# Out:
# 0.030053630547446142

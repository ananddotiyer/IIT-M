# %% [markdown]
# BA Graded Assignment 2
# Due date for this assignment: 2022-06-23, 23:59 IST.
# You may submit any number of times before the due date. The final submission will be considered for grading.
#
# Instructions:
#
# I. Please use only google collab for solving your assignments (your answers will have some variations if you are using another IDE)
#
# II. Use the file assignment2.csv to answer the questions (6) to (9)
#
# There is a firm which produces and sells two products A and B. The firm generates a profit of Rs. 150 from selling one unit of product A and Rs. 200 from selling one unit of product B. Three resources X, Y and Z are required to produce these products A and B. The firm has 22000 units of resource X, 15000 units of resource Y and 20000 units of resource Z available. The resource requirements for producing one unit of A and one unit of B are given in the table.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# The firm aims to maximize its profit by deciding on the number of units of product A and product B to produce using a linear program. Based on this scenario, answer the following questions.
#
# - What is the optimal number of product A to be produced?
# - What is the optimal number of product B to be produced?
# - What is the shadow price of resource Y at the optimum?
# - What is the shadow price of resource X at the optimum?
# - What is the shadow price of resource Z at the optimum?

# %% [markdown]
# You are provided the following dataset – assignment2.csv. You need to implement a constant elasticity model using simple linear regression on the given dataset where the independent variable is price and dependent variable is demand. After doing a log transformation on price and log transformation on demand, construct a linear regression between the transformed variables (Note: take the natural logarithm).
#
# - What is the value of R-squared?
# - What is the RMSE?
# - What is the intercept? 11.28, 8.46, -8.46, 11.28
# - What is the slope? -2.62, -1.54, 1.54, 2.62

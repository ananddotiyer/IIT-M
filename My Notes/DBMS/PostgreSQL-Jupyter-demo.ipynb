# %% [markdown]
# Need the following packages to be installed:
#
# - SQLAlchemy
# - psycopg2
# - pandas
# - ipython-sql

# %%
# %load_ext sql
# %config SqlMagic.autocommit=False

# %%
import sqlalchemy

# %%
# %sql "postgresql://postgres:sa@localhost:5432/university"

# %% [markdown]
# Get all tables in University database

# %%
# %%sql
# SELECT * FROM pg_catalog.pg_tables where schemaname='public'
# Out:
#  * postgresql://postgres:***@localhost:5432/university
# 11 rows affected.
# [('public', 'instructor', 'postgres', None, True, False, True, False),
#  ('public', 'time_slot', 'postgres', None, True, False, False, False),
#  ('public', 'teaches', 'postgres', None, True, False, True, False),
#  ('public', 'advisor', 'postgres', None, True, False, True, False),
#  ('public', 'prereq', 'postgres', None, True, False, True, False),
#  ('public', 'classroom', 'postgres', None, True, False, True, False),
#  ('public', 'course', 'postgres', None, True, False, True, False),
#  ('public', 'department', 'postgres', None, True, False, True, False),
#  ('public', 'student', 'postgres', None, True, False, True, False),
#  ('public', 'takes', 'postgres', None, True, False, True, False),
#  ('public', 'section', 'postgres', None, True, False, True, False)]

# %% [markdown]
# Trying out a few queries

# %%
# %%sql
# select dept_name from department limit 10
# Out:
#  * postgresql://postgres:***@localhost:5432/university
# 10 rows affected.
# [('Civil Eng.',),
#  ('Biology',),
#  ('History',),
#  ('Physics',),
#  ('Marketing',),
#  ('Pol. Sci.',),
#  ('English',),
#  ('Accounting',),
#  ('Comp. Sci.',),
#  ('Languages',)]

# %%
# %%sql select dept_name, (select count(*) from instructor
#                         where department.dept_name = instructor.dept_name) as num_instructors from department;
# Out:
#  * postgresql://postgres:***@localhost:5432/university
# 20 rows affected.
# [('Civil Eng.', 0),
#  ('Biology', 2),
#  ('History', 0),
#  ('Physics', 2),
#  ('Marketing', 4),
#  ('Pol. Sci.', 3),
#  ('English', 4),
#  ('Accounting', 4),
#  ('Comp. Sci.', 2),
#  ('Languages', 3),
#  ('Finance', 1),
#  ('Geology', 1),
#  ('Cybernetics', 4),
#  ('Astronomy', 1),
#  ('Athletics', 5),
#  ('Statistics', 6),
#  ('Psychology', 2),
#  ('Math', 0),
#  ('Elec. Eng.', 4),
#  ('Mech. Eng.', 2)]

# %% [markdown]
# Do all DML statements work?  Of course, yes!

# %%
# %%sql
# insert into student
# values('CS001', 'Anand', 'Comp. Sci.', null)
# Out:
#  * postgresql://postgres:***@localhost:5432/university
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "student_pkey"
# DETAIL:  Key (id)=(CS001) already exists.
#
# [SQL: insert into student
# values('CS001', 'Anand', 'Comp. Sci.', null)]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)

# %% [markdown]
# How to get the query result into a dataframe?

# %%
# %%sql
# select * from student
# order by name desc
# Out:
#  * postgresql://postgres:***@localhost:5432/university
# 2002 rows affected.
# [('38121', 'Zuyev', 'English', Decimal('98')),
#  ('84845', 'Zuo', 'Comp. Sci.', Decimal('81')),
#  ('31086', 'Zulueta', 'Psychology', Decimal('125')),
#  ('89571', 'Zubai', 'Comp. Sci.', Decimal('88')),
#  ('17424', 'Zouao', 'English', Decimal('75')),
#  ('70235', 'Zle', 'Elec. Eng.', Decimal('105')),
#  ('70099', 'Zhiyong', 'Languages', Decimal('86')),
#  ('12362', 'Zhanr', 'Civil Eng.', Decimal('115')),
#  ('40481', 'Zettel', 'Civil Eng.', Decimal('74')),
#  ('89759', 'Zettel', 'Mech. Eng.', Decimal('55')),
#  ('82063', 'Zeng', 'Athletics', Decimal('68')),
#  ('10033', 'Zelty', 'Mech. Eng.', Decimal('60')),
#  ('81175', 'Zelek', 'Biology', Decimal('0')),
#  ('45359', 'Zelek', 'Marketing', Decimal('79')),
#  ('56499', 'Zarpell', 'Geology', Decimal('82')),
#  ('95089', 'Zarpell', 'Mech. Eng.', Decimal('111')),
#  ('54612', 'Zaraté', 'Elec. Eng.', Decimal('103')),
# ...

# %%
result = _

# %%
type(result)
# Out:
# sql.run.ResultSet

# %%
df = result.DataFrame()

# %%
df
# Out:
#          id          name   dept_name tot_cred
# 0     38121         Zuyev     English       98
# 1     84845           Zuo  Comp. Sci.       81
# 2     31086       Zulueta  Psychology      125
# 3     89571         Zubai  Comp. Sci.       88
# 4     17424         Zouao     English       75
# ...     ...           ...         ...      ...
# 1997  41596        Abeggl     Finance       51
# 1998  78858  Abdul-Rahman  Psychology       49
# 1999   5144    Abdellatif     Geology       55
# 2000  64039         Aarde  Civil Eng.      120
# 2001  57962         Aarde  Statistics       22
#
# [2002 rows x 4 columns]
